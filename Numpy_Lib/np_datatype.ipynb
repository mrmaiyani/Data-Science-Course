# %%
import numpy as np

# %%
arr = np.array([16,7,3,16])

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
arr.astype('float64')
# Out:
# array([16.,  7.,  3., 16.])

# %%
arr2 = np.array([16,4,9,43], dtype = "float32")

# %%
arr2
# Out:
# array([16.,  4.,  9., 43.], dtype=float32)

# %%
arr.nbytes  #this array occupy 32 bytes bcz that have 4 element,and that int64 types use 8 bytes per element.
# Out:
# 32

# %%
arr2.nbytes    #this array occupy 16 bytes bcz that have 4 element,and that float32 types use 4 bytes per element.
# Out:
# 16

# %%
arr = np.array(['apple','banana','cherry'], dtype = 'U10')
arr
# Out:
# array(['apple', 'banana', 'cherry'], dtype='<U10')

# %%
arr = np.array([1 + 2j, 3 + 4j, 5 + 6j], dtype = 'complex128')
arr
# Out:
# array([1.+2.j, 3.+4.j, 5.+6.j])

# %%
arr = np.array([{'a': 1},[1, 2, 3], 'hello'], dtype = object)
arr
# Out:
# array([{'a': 1}, list([1, 2, 3]), 'hello'], dtype=object)
