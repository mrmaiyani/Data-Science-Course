# %%
import numpy as np

# %%
arr = np.array([12, 4, 18, 3, 4])

# %%
arr
# Out:
# array([12,  4, 18,  3,  4])

# %%
np.mean(arr)
# Out:
# np.float64(8.2)

# %%
np.std(arr)
# Out:
# np.float64(5.878775382679627)

# %%
np.var(arr)
# Out:
# np.float64(34.559999999999995)

# %%
np.min(arr)
# Out:
# np.int64(3)

# %%
np.max(arr)
# Out:
# np.int64(18)

# %%
np.sum(arr)
# Out:
# np.int64(41)

# %%
np.prod(arr) # give us product of all element means all element *(multiplication).
# Out:
# np.int64(10368)

# %%
np.median(arr)
# Out:
# np.float64(4.0)

# %%
np.percentile(arr, 10) # for the 10th percentile (median)
# Out:
# np.float64(3.4)

# %%
np.argmin(arr) # give us a index of the minimum value in an array.
# Out:
# np.int64(3)

# %%
np.argmax(arr) # give us a index of the maximun value in an array.
# Out:
# np.int64(2)

# %%
arr1 = np.array([1, 2, 3])
arr2 = np.array([4, 5, 6])

np.corrcoef(arr1, arr2) # give us correlation coefficient of an array
# Out:
# array([[1., 1.],
#        [1., 1.]])

# %%
np.unique(arr)
# Out:
# array([ 3,  4, 12, 18])

# %%
np.diff(arr) # give us difference between next element and corrent element.
# Out:
# array([ -8,  14, -15,   1])

# %%
np.cumsum(arr) # give us cumulative sum.
# Out:
# array([12, 16, 34, 37, 41])

# %%
np.linspace(4, 16, 4) #give us 4 elements from 4 to 16.
# Out:
# array([ 4.,  8., 12., 16.])

# %%
np.log(arr) # compute the natural logarithm of array.
# Out:
# array([2.48490665, 1.38629436, 2.89037176, 1.09861229, 1.38629436])

# %%
np.exp(arr) # compute the exponential of an array.
# Out:
# array([1.62754791e+05, 5.45981500e+01, 6.56599691e+07, 2.00855369e+01,
#        5.45981500e+01])
